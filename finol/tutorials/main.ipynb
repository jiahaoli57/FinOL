# %%
from finol.data_layer.data_loader import *
load_dataset_output = load_dataset()
load_dataset_output
# Out:
# Data Loading: 100%|██████████| 48/48 [00:05<00:00,  9.37it/s]
# Successfully loaded 48 Excel file(s):
# Data Processing: 100%|██████████| 48/48 [00:39<00:00,  1.21it/s]
# {'train_loader': <torch.utils.data.dataloader.DataLoader at 0x2417a3d2d90>,
#  'val_loader': <torch.utils.data.dataloader.DataLoader at 0x2417a3d2670>,
#  'test_loader': <torch.utils.data.dataloader.DataLoader at 0x2417a3d2100>,
#  'NUM_TRAIN_PERIODS': 503,
#  'NUM_VAL_PERIODS': 200,
#  'NUM_TEST_PERIODS': 201,
#  'NUM_ASSETS': 48,
#  'NUM_FEATURES_AUGMENTED': 1430,
#  'NUM_FEATURES_ORIGINAL': 143,
#  'WINDOW_SIZE': 10}

# %%
from finol.optimization_layer.model_trainer import *
train_model_output = train_model(load_dataset_output)
# Out:
# Training:   9%|▉         | 93/1000 [07:07<2:50:50, 11.30s/it]

# %%
from finol.evaluation_layer.model_evaluator import *
evaluate_model_output = evaluate_model(load_dataset_output, train_model_output)
